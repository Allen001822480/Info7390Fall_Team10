# %%
import pandas as pd

# %%
df_train = pd.read_csv('reg_data_train.csv')

# %%
df_train.head()
# Out:
#    credit_score  first_pay_date  first_time_homebuyer  maturity_date      msa  \
# 0         699.0          200505                     1         203504  39300.0
# 1         691.0          200504                     1         203503  36420.0
# 2         713.0          200503                     1         203502  28740.0
# 3         719.0          200505                     1         203504      0.0
# 4         656.0          200503                     1         203502  40340.0
#
#    mi_percentage  no_of_units occupance_status  original_cltv  \
# 0            0.0          1.0                P             56
# 1           25.0          1.0                P             90
# 2            0.0          1.0                P             72
# 3            0.0          1.0                2             85
# 4            0.0          1.0                P             68
#
#    original_dti_ratio          ...           property_state  property_type  \
# ...

# %%
X = list(set(list(df_train.columns)) - set(['original_interest_rate']))
len(X)
# Out:
# 25

# %%
y = ['original_interest_rate']

# %%
import h2o

h2o.init(strict_version_check=False,port=9957)
# Out:
# Checking whether there is an H2O instance running at http://localhost:9957. connected.
# --------------------------  ----------------------------------------
# H2O cluster uptime:         4 hours 5 mins
# H2O cluster timezone:       America/New_York
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.22.0.2
# H2O cluster version age:    15 days
# H2O cluster name:           H2O_from_python_wangying_kbgw7l
# H2O cluster total nodes:    1
# H2O cluster free memory:    3.349 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:9957
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         XGBoost, Algos, AutoML, Core V3, Core V4
# Python version:             3.6.6 final
# --------------------------  ----------------------------------------

# %%
train_df = h2o.import_file('reg_data_train.csv')
test_df = h2o.import_file('reg_data_test.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
train_df.describe()
# Out:
# Rows:351634
# Cols:26
# <table>
# <thead>
# <tr><th>       </th><th>credit_score      </th><th>first_pay_date    </th><th>first_time_homebuyer  </th><th>maturity_date     </th><th>msa               </th><th>mi_percentage     </th><th>no_of_units        </th><th>occupance_status  </th><th>original_cltv    </th><th>original_dti_ratio  </th><th>original_upb      </th><th>original_ltv     </th><th>original_interest_rate  </th><th>channel           </th><th>ppm_flag             </th><th>product_type  </th><th>property_state  </th><th>property_type     </th><th>postal_code       </th><th>loan_sequence_no  </th><th>loan_purpose      </th><th>original_loan_term  </th><th>no_of_borrowers   </th><th>seller_name  </th><th>servicer_name      </th><th>super_conforming_flag  </th></tr>
# </thead>
# <tbody>
# ...

# %%
X = list(set(list(df_train.columns)) - set(['original_interest_rate']))
Y = 'original_interest_rate'

# %%
from h2o.automl import H2OAutoML
# Set up AutoML
aml = H2OAutoML()

# %%
aml.train(x=X,y=Y,training_frame=train_df)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
aml_leaderboard_df=aml.leaderboard.as_data_frame()
aml_leaderboard_df
# Out:
#                                             model_id  mean_residual_deviance  \
# 0  StackedEnsemble_BestOfFamily_AutoML_20181207_1...                0.061811
# 1   StackedEnsemble_AllModels_AutoML_20181207_173712                0.061811
# 2                       DRF_1_AutoML_20181207_173712                0.061938
# 3                   XGBoost_1_AutoML_20181207_191701                0.061943
# 4                       DRF_1_AutoML_20181207_191701                0.062034
# 5                       XRT_1_AutoML_20181207_173712                0.065085
# 6                       XRT_1_AutoML_20181207_191701                0.065114
# 7          GLM_grid_1_AutoML_20181207_173712_model_1                0.079482
# 8          GLM_grid_1_AutoML_20181207_191701_model_1                0.079482
#
#        rmse       mse       mae     rmsle
# 0  0.248619  0.061811  0.182843  0.037073
# 1  0.248619  0.061811  0.182843  0.037073
# 2  0.248873  0.061938  0.182765  0.037102
# ...

# %%
model_set=aml_leaderboard_df['model_id']
mod_best=h2o.get_model(model_set[0])

# %%
mod_best
# Out:
# Model Details
# ...
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_AutoML_20181207_133501
# No model summary for this model
#
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0275125222633876
# RMSE: 0.1658689912653586
# LogLoss: 0.10626235967457597
# Null degrees of freedom: 180106
# Residual degrees of freedom: 180104
# Null deviance: 88062.81280740295
# Residual deviance: 38277.18962781771
# AIC: 38283.18962781771
# AUC: 0.958091637980924
# pr_auc: 0.6846908221204717
# Gini: 0.916183275961848
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.18780698817450475:
#        0       1      Error    Rate
# -----  ------  -----  -------  -----------------
# 0      165893  2238   0.0133   (2238.0/168131.0)
# 1      3483    8493   0.2908   (3483.0/11976.0)
# Total  169376  10731  0.0318   (5721.0/180107.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# ...

# %%
mod_perf = mod_best.model_performance(test_df)
mod_perf
# Out:
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on test data. **
#
# MSE: 0.08392443071396812
# RMSE: 0.2896971361853067
# MAE: 0.22248887788439475
# RMSLE: 0.042554358283407805
# R^2: 0.31720509058802915
# Mean Residual Deviance: 0.08392443071396812
# Null degrees of freedom: 405678
# Residual degrees of freedom: 405676
# Null deviance: 56710.243448041074
# Residual deviance: 34046.37912761187
# AIC: 146068.0777080654
